# %% [markdown]
# ## Without web search

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="groq:llama-3.1-8b-instant",
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="How up to date is your training knowledge?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
print(response['messages'][-1].content)
# Out:
# My training knowledge is up to date until August 2025.

# %% [markdown]
# ## Add web search tool

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

web_search.invoke("Resultyst")
# Out:
# {'query': 'Resultyst',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://resultyst.xyz/',
#    'title': 'Resultyst -> SuN',
#    'content': 'Resultyst is a personal lab for exploring the frontiers of artificial intelligence and data science. Here, ideas are tested, models are trained, and innovations',
#    'score': 0.9284155,
#    'raw_content': None},
#   {'url': 'https://github.com/Resultyst',
#    'title': 'Resultyst - GitHub',
#    'content': 'Hi, Resultyst is a personal brand of Suryaa07. Currently learning AI, LLM, Cloud Computing. Ask me about Artificial Intelligence, Data Science,',
#    'score': 0.8512743,
#    'raw_content': None},
#   {'url': 'https://www.instagram.com/resultyst/',
#    'title': 'Suryaa Narayanan K (@resultyst) • Instagram photos and videos',
#    'content': '1.1K+ followers · 1.5K+ following · 123 posts · @resultyst: “AI/GenAI explorer & Automation Engineer Researching concepts, tools & real-world applications',
#    'score': 0.65676886,
#    'raw_content': None},
#   {'url': 'https://leetcode.com/u/resultyst/',
#    'title': 'resultyst - LeetCode Profile',
#    'content': 'Passionate Learner❤️\u200d | Future-Ready Technologist \u200d | Tech Explorer . 0. Following. 0. Followers. TCS | ASE. India. Rajalakshmi Institute of Technology.',
#    'score': 0.63098115,
#    'raw_content': None},
#   {'url': 'https://www.linkedin.com/posts/resultyst7_resultyst-ai-softskills-activity-7280222942477611008-pKzM',
#    'title': '#resultyst #ai #softskills | Suryaa Narayanan K - LinkedIn',
#    'content': 'I was a rookie with 0 experience. I needed money. When I first started my journey in AI (Resultyst), I had no clue what I was getting into.',
#    'score': 0.44869256,
#    'raw_content': None}],
#  'response_time': 0.78,
#  'request_id': 'e30bb548-8c42-4aec-8913-23d2e7df9721'}

# %%
agent = create_agent(
    model="groq:llama-3.1-8b-instant",
    tools=[web_search]
)

question = HumanMessage(content="Who is know as Resultyst and what it is")

response = agent.invoke(
    {"messages": [question]}
)

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content='Who is know as Resultyst and what it is', additional_kwargs={}, response_metadata={}, id='2a43a179-b475-470a-890b-1d9ddab88b2c'),
#  AIMessage(content='<web_search>query="Resultyst"</web_search>', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 220, 'total_tokens': 233, 'completion_time': 0.028360875, 'completion_tokens_details': None, 'prompt_time': 0.025079138, 'prompt_tokens_details': None, 'queue_time': 0.046527892, 'total_time': 0.053440013}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019d44ab-2787-7491-b691-24a59fb77ae3-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 220, 'output_tokens': 13, 'total_tokens': 233})]

# %% [markdown]
# trace: https://smith.langchain.com/public/59432173-0dd6-49e8-9964-b16be6048426/r
